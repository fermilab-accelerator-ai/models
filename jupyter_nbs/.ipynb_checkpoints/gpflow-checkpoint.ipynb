# %% [markdown]
# We want to understand the time dependence of the data. To do so, we try to use Gaussian Processes from GPFlow, which is powered by TensorFlow.

# %%
# import libs && tools
import numpy as np
import pandas as pd
import gpflow
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,6)
plt = matplotlib.pyplot
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0616 13:55:47.418761 18576 deprecation_wrapper.py:118] From C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\session_manager.py:31: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0616 13:55:47.423761 18576 deprecation_wrapper.py:118] From C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\misc.py:25: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0616 13:55:47.546770 18576 deprecation_wrapper.py:118] From C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\saver\coders.py:80: The name tf.data.Iterator is deprecated. Please use tf.compat.v1.data.Iterator instead.

# %%
# import and handle data
df = pd.read_csv('../data/20190606180000-20190606190000.csv')
df=df.replace([np.inf, -np.inf], np.nan)
df=df.dropna();
df=df.round(decimals=5)  # round to one decimal after precision of devices
df['diff'] = (df['B_VIMIN'] - df['B:VIMIN'])
df2= pd.DataFrame({'diff' : df['diff'], 'err' : df['B:IMINER']})
col1,col2,col3='B:IMINER','B:VIMIN','B_VIMIN'

# %%
# define period of TLG
horizon = 61.4; # unit: sec. horizon of TLG..61.-- sec
cycle   = 15; # 15Hz sampling
supercycle = int(cycle*horizon);

num_train = 1*supercycle

# %%
X = df[col1][0:num_train].values
n = len(X)
K = np.exp(-0.5*np.square(X - X.T)/0.01) + np.eye(n)*1e-6
f = np.dot(np.linalg.cholesky(K), np.random.randn(n, 1))

plt.plot(X, f, '.')
plt.ylabel('latent function value')

Y = np.round((f + f.min())*3)
Y = Y - Y.min()
Y = np.asarray(Y, np.float64)


plt.twinx()
plt.plot(X, Y, 'kx', mew=1.5)
plt.ylabel('observed data value')
# Out:
# Text(0, 0.5, 'observed data value')

# %%
# construct ordinal likelihood
bin_edges = np.array(np.arange(np.unique(Y).size + 1), dtype=float)
bin_edges = bin_edges - bin_edges.mean()
likelihood=gpflow.likelihoods.Ordinal(bin_edges)

# build a model with this likelihood
m = gpflow.models.VGP(X, Y,
                   kern=gpflow.kernels.Matern32(1),
                   likelihood=likelihood)

#fit the model
gpflow.train.ScipyOptimizer().minimize(m)
# Out:
# W0616 13:57:15.106739 18576 deprecation.py:323] From C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\ops\array_grad.py:199: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#
# InvalidArgumentError: Requires start <= limit when delta > 0: 0/-1
# 	 [[{{node VGP-34d9d1e0-18/matrix_transpose/Range}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-7-4c7b5a312b8e> in <module>
#      10
#      11 #fit the model
# ---> 12 gpflow.train.ScipyOptimizer().minimize(m)
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\training\scipy_optimizer.py in minimize(self, model, session, var_list, feed_dict, maxiter, disp, initialize, anchor, step_callback, **kwargs)
#      87         feed_dict = self._gen_feed_dict(model, feed_dict)
#      88         optimizer.minimize(session=session, feed_dict=feed_dict, step_callback=step_callback,
# ---> 89                            **kwargs)
#      90         if anchor:
#      91             model.anchor(session)
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\training\external_optimizer.py in minimize(self, session, feed_dict, fetches, step_callback, loss_callback, **run_kwargs)
#     173         packed_bounds=self._packed_bounds,
#     174         step_callback=step_callback,
# --> 175         optimizer_kwargs=self.optimizer_kwargs)
#     176     var_vals = [
#     177         packed_var_val[packing_slice] for packing_slice in self._packing_slices
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\training\external_optimizer.py in _minimize(self, initial_val, loss_grad_func, equality_funcs, equality_grad_funcs, inequality_funcs, inequality_grad_funcs, packed_bounds, step_callback, optimizer_kwargs)
#     434
#     435     import scipy.optimize  # pylint: disable=g-import-not-at-top
# --> 436     result = scipy.optimize.minimize(*minimize_args, **minimize_kwargs)
#     437     logging.info('Optimization terminated with:\n'
#     438                  '  Message: %s\n'
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     599     elif meth == 'l-bfgs-b':
#     600         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 601                                 callback=callback, **options)
#     602     elif meth == 'tnc':
#     603         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     283     else:
#     284         def func_and_grad(x):
# --> 285             f = fun(x, *args)
#     286             g = jac(x, *args)
#     287             return f, g
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      61     def __call__(self, x, *args):
#      62         self.x = numpy.asarray(x).copy()
# ---> 63         fg = self.fun(x, *args)
#      64         self.jac = fg[1]
#      65         return fg[0]
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\training\external_optimizer.py in loss_grad_func_wrapper(x)
#     396     def loss_grad_func_wrapper(x):
#     397       # SciPy's L-BFGS-B Fortran implementation requires gradients as doubles.
# --> 398       loss, gradient = loss_grad_func(x)
#     399       return loss, gradient.astype('float64')
#     400
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\training\external_optimizer.py in eval_func(x)
#     307
#     308       augmented_fetch_vals = session.run(
# --> 309           augmented_fetches, feed_dict=augmented_feed_dict)
#     310
#     311       if callable(callback):
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1368           pass
#    1369       message = error_interpolation.interpolate(message, self._graph)
# -> 1370       raise type(e)(node_def, op, message)
#    1371
#    1372   def _extend_graph(self):
#
# InvalidArgumentError: Requires start <= limit when delta > 0: 0/-1
# 	 [[node VGP-34d9d1e0-18/matrix_transpose/Range (defined at C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\kernels.py:270) ]]
#
# Original stack trace for 'VGP-34d9d1e0-18/matrix_transpose/Range':
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\asyncio\base_events.py", line 539, in run_forever
#     self._run_once()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\asyncio\base_events.py", line 1775, in _run_once
#     handle._run()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tornado\gen.py", line 781, in inner
#     self.run()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tornado\gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\ipykernel\kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\ipykernel\kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\ipykernel\kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\IPython\core\interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\IPython\core\interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\IPython\core\interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\IPython\core\interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-4c7b5a312b8e>", line 9, in <module>
#     likelihood=likelihood)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\core\compilable.py", line 90, in __init__
#     self.build()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\core\node.py", line 156, in build
#     self._build()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\models\model.py", line 79, in _build
#     likelihood = self._build_likelihood()
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\decors.py", line 67, in tensor_mode_wrapper
#     result = method(obj, *args, **kwargs)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\models\vgp.py", line 106, in _build_likelihood
#     K = self.kern.K(self.X) + tf.eye(self.num_data, dtype=settings.float_type) * \
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\decors.py", line 67, in tensor_mode_wrapper
#     result = method(obj, *args, **kwargs)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\kernels.py", line 318, in K
#     return self.K_r2(self.scaled_square_dist(X, X2))
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\kernels.py", line 286, in scaled_square_dist
#     return self._scaled_square_dist(X, X2)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\decors.py", line 67, in tensor_mode_wrapper
#     result = method(obj, *args, **kwargs)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\gpflow\kernels.py", line 270, in _scaled_square_dist
#     dist += Xs + tf.matrix_transpose(Xs)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\ops\array_ops.py", line 1804, in matrix_transpose
#     (gen_math_ops._range(0, a_rank - 2, 1), [a_rank - 1, a_rank - 2]), 0)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 8128, in _range
#     "Range", start=start, limit=limit, delta=delta, name=name)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\framework\ops.py", line 3299, in create_op
#     op_def=op_def)
#   File "C:\Users\Rachael\.conda\envs\py3tf1gnt\lib\site-packages\tensorflow\python\framework\ops.py", line 1692, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
plt.figure(figsize=(14, 6))
Xtest = np.linspace(m.X.read_value().min(), m.X.read_value().max(), 100).reshape(-1, 1)
mu, var = m.predict_y(Xtest)
line, = plt.plot(Xtest, mu, lw=2)
col=line.get_color()
plt.plot(Xtest, mu+2*np.sqrt(var), '--', lw=2, color=col)
plt.plot(Xtest, mu-2*np.sqrt(var), '--', lw=2, color=col)
plt.plot(m.X.read_value(), m.Y.read_value(), 'kx', mew=2)

# %%
# to see the predictive density, try predicting every possible value.
def pred_density(m):
    Xtest = np.linspace(m.X.read_value().min(), m.X.read_value().max(), 100).reshape(-1, 1)
    ys = np.arange(m.Y.read_value().max()+1)
    densities = []
    for y in ys:
        Ytest = np.ones_like(Xtest) * y
        densities.append(m.predict_density(Xtest, Ytest))
    return np.hstack(densities).T

# %%
plt.imshow(np.exp(pred_density(m)), interpolation='nearest',
           extent=[m.X.read_value().min(), m.X.read_value().max(), -0.5, m.Y.read_value().max()+0.5],
           origin='lower', aspect='auto', cmap=plt.cm.viridis)
plt.colorbar()
plt.plot(X, Y, 'kx', mew=2, scalex=False, scaley=False)
